# %% [markdown]
# <a href="https://colab.research.google.com/github/jaswanthmathan/project01/blob/main/webscrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

i = requests.get("https://en.wikipedia.org/wiki/Yuvan_Shankar_Raja")
j=i.content
doc= BeautifulSoup(j,"lxml")
doc
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Yuvan Shankar Raja - Wikipedia</title>
# ...

# %%
table = doc.find_all("table")
ta = table[0]
ta
# Out:
# <table class="infobox vcard plainlist"><tbody><tr><th class="infobox-above" colspan="2" style="background-color: #b0c4de; font-size: 125%;"><div class="">Yuvan Shankar Raja</div></th></tr><tr><td class="infobox-image" colspan="2"><a class="image" href="/wiki/File:Yuvan_Shankar_Raja_exclusive_HQ_Photos_Silverscreen.jpg" title="Raja in 2013"><img alt="Raja in 2013" data-file-height="1200" data-file-width="800" decoding="async" height="330" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b6/Yuvan_Shankar_Raja_exclusive_HQ_Photos_Silverscreen.jpg/220px-Yuvan_Shankar_Raja_exclusive_HQ_Photos_Silverscreen.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b6/Yuvan_Shankar_Raja_exclusive_HQ_Photos_Silverscreen.jpg/330px-Yuvan_Shankar_Raja_exclusive_HQ_Photos_Silverscreen.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b6/Yuvan_Shankar_Raja_exclusive_HQ_Photos_Silverscreen.jpg/440px-Yuvan_Shankar_Raja_exclusive_HQ_Photos_Silverscreen.jpg 2x" width="220"/></a><div 
# ...

# %%
df1.shape
# Out:
# (13, 3)

# %%
ta.find("th").get_text()== "#"
# Out:
# False

# %%
from pandas.io.formats.style_render import DataFrame
df = pd.read_html(str(ta))
df1 = pd.DataFrame(df[0])
df1
# Out:
#        Yuvan Shankar Raja                               Yuvan Shankar Raja.1
# 0            Raja in 2013                                       Raja in 2013
# 1  Background information                             Background information
# 2              Birth name                                 Yuvan Shankar Raja
# 3                    Born                  (age 43) Theni, Tamil Nadu, India
# 4                  Origin                                  Tamil Nadu, India
# 5                  Genres                            Film score, world music
# 6           Occupation(s)  .mw-parser-output .hlist dl,.mw-parser-output ...
# 7           Instrument(s)                           Guitar, keyboard, vocals
# 8            Years active                                       1996–present
# 9                  Labels  Sony Music, Think Music India, U1 Records and ...

# %%
df1.to_csv('webscrapping.U1')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Yuvan Shankar Raja    10 non-null     object
#  1   Yuvan Shankar Raja.1  10 non-null     object
# dtypes: object(2)
# memory usage: 288.0+ bytes

# %%
df1.describe()
# Out:
#        Yuvan Shankar Raja Yuvan Shankar Raja.1
# count                  10                   10
# unique                 10                   10
# top          Raja in 2013         Raja in 2013
# freq                    1                    1
